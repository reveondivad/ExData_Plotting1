# %% [markdown]
# <a href="https://colab.research.google.com/github/reveondivad/ExData_Plotting1/blob/master/DataAugmentor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://towardsdatascience.com/exploring-image-data-augmentation-with-keras-and-tensorflow-a8162d89b844

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib.pyplot import imread, imshow, subplots, show


def plot(data_generator):
    """
    Plots 4 images generated by an object of the ImageDataGenerator class.
    """
    data_generator.fit(images)
    image_iterator = data_generator.flow(images)
    
    # Plot the images given by the iterator
    fig, rows = subplots(nrows=1, ncols=4, figsize=(18,18))
    for row in rows:
        row.imshow(image_iterator.next()[0].astype('int'))
        row.axis('off')
    show()
    
image = imread("image.jpg")

# Creating a dataset which contains just one image.
images = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

imshow(images[0])
show()

# %% [markdown]
# #Rotate

# %%
data_generator = ImageDataGenerator(rotation_range=90)
plot(data_generator)

# %% [markdown]
# #Width shifting

# %%
data_generator = ImageDataGenerator(width_shift_range=0.3)
plot(data_generator)

# %% [markdown]
# #Height shifting

# %%
data_generator = ImageDataGenerator(height_shift_range=0.3)
plot(data_generator)

# %% [markdown]
# #Brightness

# %%
data_generator = ImageDataGenerator(brightness_range=(0.1, 0.9))
plot(data_generator)

# %% [markdown]
# #Shear Intensity

# %%
data_generator = ImageDataGenerator(shear_range=45.0)
plot(data_generator)

# %% [markdown]
# #Zoom

# %%
data_generator = ImageDataGenerator(zoom_range=[0.5, 1.5])
plot(data_generator)

# %% [markdown]
# #Channel shift

# %%
data_generator = ImageDataGenerator(channel_shift_range=150.0)
plot(data_generator)

# %% [markdown]
# #Horizontal Flip

# %%
data_generator = ImageDataGenerator(horizontal_flip=True)
plot(data_generator)

# %% [markdown]
# #Vertical Flip

# %%
data_generator = ImageDataGenerator(vertical_flip=True)
plot(data_generator)

# %% [markdown]
# #Fill Nearest

# %%
data_generator = ImageDataGenerator(width_shift_range=0.3, fill_mode='nearest')
plot(data_generator)

# %% [markdown]
# #Reflect

# %%
data_generator = ImageDataGenerator(width_shift_range=0.3, fill_mode='reflect')
plot(data_generator)

# %% [markdown]
# #Wrap

# %%
data_generator = ImageDataGenerator(width_shift_range=0.3, fill_mode='wrap')
plot(data_generator)

# %% [markdown]
# #Constant Fill

# %%
data_generator = ImageDataGenerator(width_shift_range=0.3, 
                                    fill_mode='constant', 
                                    cval=190)
plot(data_generator)

# %% [markdown]
# There are some additional benefits that you can harness straight out of this class. Some examples include zero centering the data (featurewise_center, samplewise_center) and normalization (featurewise_std_normalization, samplewise_std_normalization). These variables can be set by passing their boolean value to the ImageDataGenerator class. We can also rescale the values by specifying the rescale argument, which gets multiplied to all the values.
